# %%
import pandas as pd

# %%
print("Hello")
# Out:
# Hello

# %%
1234
# Out:
# 1234

# %% [markdown]
# 1 Hello World

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Frank")
# Out:
# Frank

# %%
"Hello World".upper()
# Out:
# 'HELLO WORLD'

# %%
"Hello World".replace("o","l")
# Out:
# 'Helll Wlrld'

# %% [markdown]
# 4 List

# %%
countries = ['usa','brazil','india']

# %%
countries
# Out:
# ['usa', 'brazil', 'india']

# %% [markdown]
# slicing

# %%
#slicing
#list_name[start,stop]

# %%
countries[0:3]
# Out:
# ['usa', 'brazil', 'india']

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Data Types

# %% [markdown]
# so there are many types of data types --- int, float,str,boolean
# if we talk about bool-- True[1],
# False[0]

# %%
#Integer
11
# Out:
# 11

# %%
#Floating
11.11
# Out:
# 11.11

# %%
#String
type("Hryy")
# Out:
# str

# %% [markdown]
# What is the data type of the result of: 6 / 2?

# %%
type(6/2)
# Out:
# float

# %% [markdown]
# What is the type of the result of: "Hello, World!"

# %%
type("Hello, World!")
# Out:
# str

# %% [markdown]
# What is the type of the result of: "hello" == "world"

# %%
type("hello" == "world")# because here == sign make condition whether hello is some how equal to world and it contain len equal so over answer is True
# Out:
# bool

# %% [markdown]
# Write the code to convert this number representing financial value "1234.56" to a floating point number

# %%
float("1234.56")
# Out:
# 1234.56

# %% [markdown]
# Write the code to convert this phone number 123-456-7890 to a string

# %%
str(123-456-7890)
# Out:
# '-8223'

# %% [markdown]
# Question 1
# What is the result of the operation: 11//2

# %%
11//2
# Out:
# 5

# %% [markdown]
# Question 2
# What is the value of x after the following is run:
#
# x=4
#
# x=x/2

# %%
x = 4
x = 4/2
x
# Out:
# 2.0

# %%
3*"The best album "
# Out:
# 'The best album The best album The best album '

# %% [markdown]
# Escape Sequences

# %%
print('The bodyGuard\n is the best album')
# Out:
# The bodyGuard
#  is the best album

# %%
a = "Thriller is the sixth studio album"
print("Before upper case",a)
b = a.upper()
print("after upper case",b)
# Out:
# Before upper case Thriller is the sixth studio album
# after upper case THRILLER IS THE SIXTH STUDIO ALBUM

# %%
a = "The BodyGuard is the best album"
b = a.replace("BodyGuard","Divya")
b
# Out:
# 'The Divya is the best album'

# %%
name = "The BodyGuard"
name.find("he")
# Out:
# 1

# %%
name.find('Guard')
# Out:
# 8

# %%
name = "The BodyGuard"
split_string = name.split()
split_string
# Out:
# ['The', 'BodyGuard']

# %% [markdown]
# Regex --- for matching and handling strings,
# This regex module provide several functions for providing for working with regular expression  including search,split,findall,sub

# %%
import re

s1 = "The best movies of all time is radha"

#define the term to search for
search = r"best"
result = re.search(search,s1)
if search:
    print("condition")
else:
    print("fail")
# Out:
# condition

# %%
"helloMike".find("Mike")
# Out:
# 5

# %%
morning_temp = 22

evening_temp = morning_temp - 3
evening_temp
# Out:
# 19

# %%
print("Python is \"awesome\"")
# Out:
# Python is "awesome"

# %% [markdown]
# List

# %%
a = [1,2,3] + [1,1,1]
a
# Out:
# [1, 2, 3, 1, 1, 1]

# %%
set(['rap','house','electronic music', 'rap'])
# Out:
# {'electronic music', 'house', 'rap'}

# %%
age = 20
if age > 30:
    print("i am ready")
elif age == 20:
    print("what can i do ")
else:
    print("condition applied")

print("move on")
# Out:
# what can i do
# move on

# %%
def calculate_value(a,b):
    total = a+b
    return total
result  = calculate_value(4,6)
print(result)
# Out:
# 10

# %%
a = 4
b = 6
c = a+ b
print(c)
# Out:
# 10

# %%
def greet(name):
    return "hello" + name
for _ in range(3):
    print(greet("Alice"))
# Out:
# helloAlice
# helloAlice
# helloAlice

# %%
def multi(a,b):
    c = a*b
    return c
result = multi(3,5)
print(result)
# Out:
# 15

# %%
def type_of_album(album,year_of_album):
    print(album,year_of_album)
    if year_of_album > 1940:
        print("all done")
    else:
        print("not done")
x = type_of_album("The bodyguard",1940)
print(x)
# Out:
# The bodyguard 1940
# not done
# None

# %%
len(['A','B',1])
# Out:
# 3

# %%
len([sum([1,1,1])])
# Out:
# 1

# %%
def print_value(A):
    for a in A:
        print(a + '1')
print_value(["a","b","c"])
# Out:
# a1
# b1
# c1

# %% [markdown]
# **Exercise 1: Handling ZeroDivisionError**
#
# **Imagine you have two numbers and want to determine what happens when you divide one number by the other. To do this, you need to create a Python function called safe_divide. You give this function two numbers, a 'numerator' and a 'denominator'. The 'numerator' is the number you want to divide, and the 'denominator' is the number you want to divide by. Use the user input method of Python to take the values.**
#
# **The function should be able to do the division for you and give you the result. But here's the catch: if you try to divide by zero (which is not allowed in math), the function should be smart enough to catch that and tell you that it's not possible to divide by zero. Instead of showing an error, it should return None, which means 'nothing' or 'no value', and print "Error: Cannot divide by Zero**

# %%
def safe_divide(numerator,denominator):
    
    try:
        result = numerator/denominator
        return result
    except ZeroDivisionError:
        print("Error:Number can not br divided by Zero")
        return None

#Test Case
numerator = int(input("Enter the number:"))
denominator = int(input("Enter theDEnominator:"))
print(safe_divide(numerator,denominator))
# Out:
# 0.5217391304347826

# %%
import math
def square_root(number1):
    try:
        result = math.sqrt(number1)
        print("your result is here")
    except ValueError:
        print("'Invalid input! Please enter a positive integer or a float value.")
#test case
number1 = int(input("Enter your number"))
square_root(number1)
# Out:
# your result is here

# %% [markdown]
# **Task-1. You are tasked with creating a Python program to represent vehicles using a class. Each car should have attributes for maximum speed and mileage.**

# %%
class vehicle:

    def __init__(self,max_speed,mileage):
        self.speed = max_speed
        self.mileage = mileage

# %% [markdown]
# ### Task-2. Update the class with the default color for all vehicles," white".

# %%
class vehicle:
    color = 'White'
    def __init__(self,max_speed,mileage):
        self.speed = max_speed
        self.mileage = mileage
        self.seating_capacity = None
    def seating_capacity(self,seating_capacity):
        self.seating_capacity = seating_capacity

# %% [markdown]
# ### Task-3. Additionally, you need to create methods in the Vehicle class to assign seating capacity to a vehicle.

# %%
class vehicle:
    color = 'White'
    def __init__(self,max_speed,mileage):
        self.speed = max_speed
        self.mileage = mileage
        self.seating_capacity = None
    def seating_capacity(self,seating_capacity):
        self.seating_capacity = seating_capacity

# %% [markdown]
# ### Task-4. Create a method to display all the properties of an object of the class.

# %%
class vehicle:
    color = 'white'
    def __init__(self,max_speed,mileage):
        self.speed = max_speed
        self.mileage = mileage
        self.seating_capacity = None
    def seating_capacity(self,seating_capacity):
        self.seating_capacity = self.seating_capacity

    def display_all_propeties(self):
        print("speed of car",self.max_speed)
        print("mileage of car",self.mileage)
        print("seating_capacity of car",self.seating_capacity)
        print("color of the car",self.color)

# %% [markdown]
# ### Task-5. Additionally, you need to create two objects of the Vehicle class object that should have a max speed of 200kmph and mileage of 20kmpl with five seating capacities, and another car object should have a max speed of 180kmph and mileage of 25kmpl with four seating capacities

# %%
class Vehicle:
    color = "White"
    def __init__(self,max_speed,mileage):
        self.max_speed = max_speed
        self.mileage =  mileage
        self.seating_capacity = None


    def assign_seating_capacity(self,seating_capacity):
        self.seating_capacity = seating_capacity

    def display_properties(self):
        print("Properties of the vehicles:")
        print("color of the car:",self.color)
        print("max_speed of the car:", self.max_speed)
        print("mileage of the car:" ,self.mileage)
        print("seating_capacity of the car:",self.seating_capacity)

#craeting object of the car
vehicle1 = Vehicle(200,20)
vehicle1.assign_seating_capacity(5)
vehicle1.display_properties()

vehicle2 = Vehicle(180,25)
vehicle2.assign_seating_capacity(4)
vehicle2.display_properties()
# Out:
# Properties of the vehicles:
# color of the car: White
# max_speed of the car: 200
# mileage of the car: 20
# seating_capacity of the car: 5
# Properties of the vehicles:
# color of the car: White
# max_speed of the car: 180
# mileage of the car: 25
# seating_capacity of the car: 4

# %%
# type your code here
givenstring="Lorem ipsum dolor! diam amet, consetetur Lorem magna. sed diam nonumy eirmod tempor. diam et labore? et diam magna. et diam amet."
class TextAnalyzer(object):
    def __init__(self,text):
        formatted_text =text.replace('.','').replace(',','').replace('!','').replace('?','')
        formatted_text = formatted_text.lower()
        self.fmtText = formatted_text

    def freqAll(self):
        wordList = self.fmtText.split()
        freqMap ={}
        for word in set(wordList):
            freqMap[word] = wordList.count(word)
        return freqMap

    def freqOf(self,word):
        freqDict = self.freqAll()
        if word in freqDict:
            return freqDict[word]
        else:
            return 0


analyzed =TextAnalyzer(givenstring)
word = "amet"
freq_b = analyzed.freqOf(word)
print("The word",word,"appears",freq_b,"times.")
# Out:
# The word amet appears 2 times.

# %%
givenstring="Lorem ipsum dolor! diam amet, consetetur Lorem magna. sed diam nonumy eirmod tempor. diam et labore? et diam magna. et diam amet."

class TextAnalyzer:
    def __init__(self,text):
        textformatting = text.replace('.','').replace('!','').replace('?','').replace(',','')

        textformatting= textformatting.lower()
        self.fmttxt = textformatting

# %%
x = 1 
x = x > 5

# %%
class Points(object):
    def __init__(self, x, y): 
        self.x = x 
        self.y = y 
    def print_point(self): 
        print('x=', self.x, ' y=', self.y) 
p1 = Points("A", "B") 
p1.print_point()
# Out:
# x= A  y= B

# %%
class WeatherData:
    def __init__(self, temp_c, humidity):
        self.temp_c = temp_c
        self.humidity = humidity
    def display(self):
        print(f"Temperature: {self.temp_c}°C, Humidity: {self.humidity}%")
today = WeatherData(22, 45)
today.temp_c = 25
today.display()
# Out:
# Temperature: 25°C, Humidity: 45%

# %%
def delta(x): 
    if x == 0: 
        y = 1 
    else: 
        y = 0 
    return y

# %%
a = 1 
def do(x): 
    a = 100 
    return x + a 
print(do(1))
# Out:
# 101

# %%
class Coordinate(object):
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def display(self):
        print(f"Position: ({self.x}, {self.y})")
cursor = Coordinate(15, 30)
cursor.display()
# Out:
# Position: (15, 30)

# %%
items = ["Vase", "Statue", "Mask"]
for index, item in enumerate(items, start=1):
    print(f"Exhibit {index}: {item} - Ancient Greece")
# Out:
# Exhibit 1: Vase - Ancient Greece
# Exhibit 2: Statue - Ancient Greece
# Exhibit 3: Mask - Ancient Greece

# %%
Lines = ["This is line 1", "This is line 2", "This is line 3"]

with open ("file",'w')as file1:
    for line in Lines:
        file1.write(line + '/')

# %%
import numpy as np
a=np.array([-1,1])
b=np.array([1,1]) 
np.dot(a,b)
# Out:
# np.int64(0)

# %%
X=np.array([[1,0,1],[2,2,2]]) 
X.ndim
# Out:
# 2
