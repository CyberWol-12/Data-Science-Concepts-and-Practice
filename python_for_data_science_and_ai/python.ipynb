# %%
import pandas as pd

# %%
print("Hello")
# Out:
# Hello

# %%
1234
# Out:
# 1234

# %% [markdown]
# 1 Hello World

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Frank")
# Out:
# Frank

# %%
"Hello World".upper()
# Out:
# 'HELLO WORLD'

# %%
"Hello World".replace("o","l")
# Out:
# 'Helll Wlrld'

# %% [markdown]
# 4 List

# %%
countries = ['usa','brazil','india']

# %%
countries
# Out:
# ['usa', 'brazil', 'india']

# %% [markdown]
# slicing

# %%
#slicing
#list_name[start,stop]

# %%
countries[0:3]
# Out:
# ['usa', 'brazil', 'india']

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Data Types
