# %%
type(11)
# Out:
# int

# %%
type(21.123)
# Out:
# float

# %%
type("Hello")
# Out:
# str

# %%
int(2.0)
# Out:
# 2

# %%
float(2)
# Out:
# 2.0

# %%
int(True)
# Out:
# 1

# %%
bool(1)
# Out:
# True

# %% [markdown]
# #types

# %% [markdown]
# Expression

# %%
total_min = 23+334+34
total_hrs = total_min/60
total_hrs
# Out:
# 6.516666666666667

# %%
import sys
print(sys.version)
# Out:
# 3.13.14 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:26:41) [MSC v.1942 64 bit (AMD64)]

# %%
print("Hello World!") # this line prints the strings
# Out:
# Hello World!

# %%
import re

s1 = "The Bodyguard is the best album"
pattern = r"Body"
result = re.search(pattern,s1)
if result:
    print("Match found")
else:
    print("Match not found")
# Out:
# Match found

# %%
album_list = [ "Michael Jackson", "Thriller", 1982, "00:42:19", \
              "Pop, Rock, R&B", 46.0, 65, "30-Nov-82", None, 10.0]
album_set = set(album_list)
album_set
# Out:
# {'00:42:19',
#  10.0,
#  1982,
#  '30-Nov-82',
#  46.0,
#  65,
#  'Michael Jackson',
#  None,
#  'Pop, Rock, R&B',
#  'Thriller'}

# %%
album_year = 1989
if(album_year >1976) or (album_year <1990):
    print("This album is mine")
else:
    print("This album is  not mine")
# Out:
# This album is mine

# %%
square = ['Orange','Orange','Purple','blue']
NewSquare = []
i = 0
while(square[i] == 'Orange'):
    NewSquare.append(square[i])
    i = i+1

# %%
def type_of_album(album,release_year):
    print(album,release_year)
    if release_year > 1980:
        print("yes")
    else:
        print("not done yet")
type_of_album("Bodyguards",1990)
# Out:
# Bodyguards 1990
# yes

# %%
a = 1
def add(b):
    return a+b
c = add(10)
c
# Out:
# 11

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class Circle(object):

    #constructor
    def __init__(self,radius =4,color = 'Blue'):
        self.radius = radius
        self.color = color

    #method
    def add_radius(self,r):
        self.radius = self.radius + r
        return(self.radius)

    #method
    def draw_circle(self):
        plt.gca().add_patch(plt.Circle((0,0),radius  = self.radius,fc = self.color))
        plt.axis()
        plt.show()

Redcircle = Circle(10,'Red')
Redcircle.draw_circle()
