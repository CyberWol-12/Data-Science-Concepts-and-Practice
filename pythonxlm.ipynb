# %%
# !pip install pandas numpy 
# !pip install lxml

# %%
import pandas as pd 
import numpy as np

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')
