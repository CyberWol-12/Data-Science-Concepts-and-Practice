# %%
import pandas as pd

# %%
print("Hello")
# Out:
# Hello

# %%
1234
# Out:
# 1234

# %% [markdown]
# 1 Hello World

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Frank")
# Out:
# Frank

# %%
"Hello World".upper()
# Out:
# 'HELLO WORLD'
